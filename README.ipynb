# %% [markdown]
# # Business

# %%
import pandas as pd
usd = pd.read_csv('./data/statement_20394382_USD_2021-06-05_2026-02-21.csv')
pln = pd.read_csv('./data/statement_20410800_PLN_2021-06-05_2026-02-21.csv')
eur = pd.read_csv('./data/statement_20915923_EUR_2021-06-05_2026-02-21.csv')
usd['Account'] = 'USD'
pln['Account'] = 'PLN'
eur['Account'] = 'EUR'
statement = pd.concat([usd, pln, eur])
statement.to_csv('./data/statement_2021-06-05_2026-02-21.csv')
